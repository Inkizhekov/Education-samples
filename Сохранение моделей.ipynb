# %% [markdown]
# # Импорт библиотек

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [raw]
# tf.keras

# %% [markdown]
# Версии

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
np.__version__
# Out:
# '1.21.6'

# %%
import sys
sys.version
# Out:
# '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]'

# %% [markdown]
# ---

# %% [markdown]
# # Сохранение базовой модели

# %% [markdown]
# Пример модели

# %%
def get_model():
    inputs = keras.Input(shape=(32,))
    outputs = keras.layers.Dense(1)(inputs)
    
    model = keras.Model(inputs, outputs)
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    return model

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Имитация набора данных
test_input = np.random.random((2048, 32))
test_target = np.random.random((2048, 1))

# %%
test_input.shape
# Out:
# (2048, 32)

# %%
test_input
# Out:
# array([[0.2011437 , 0.85324945, 0.05941495, ..., 0.36163314, 0.53527533,
#         0.98780428],
#        [0.45724   , 0.48054038, 0.85679464, ..., 0.29831916, 0.14654436,
#         0.72577593],
#        [0.5880887 , 0.87493642, 0.45814791, ..., 0.57591148, 0.37001112,
#         0.50847751],
#        ...,
#        [0.9416628 , 0.04416769, 0.03945241, ..., 0.65333832, 0.79990988,
#         0.95756591],
#        [0.10549175, 0.45123744, 0.90249194, ..., 0.54909527, 0.68324617,
#         0.51242744],
#        [0.44368618, 0.63687818, 0.81791455, ..., 0.16475261, 0.74651811,
#         0.30725423]])

# %%
model.fit(test_input, test_target, epochs=4)
# Out:
# Epoch 1/4
# 64/64 [==============================] - 1s 2ms/step - loss: 0.4283
# Epoch 2/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2171
# Epoch 3/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2082
# Epoch 4/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1987

# %%
model.fit(test_input, test_target, epochs=10)
# Out:
# Epoch 1/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1881
# Epoch 2/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1776
# Epoch 3/10
# 64/64 [==============================] - 0s 1ms/step - loss: 0.1675
# Epoch 4/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1579
# Epoch 5/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1488
# Epoch 6/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1402
# Epoch 7/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1324
# Epoch 8/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1259
# Epoch 9/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1193
# Epoch 10/10
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1138

# %%
# ?model.fit

# %% [markdown]
# Сохранение

# %%
model_path = "my_model_1"

# %%
model.save(model_path)

# %% [markdown]
# Загрузка модели

# %%
reconstructed_model = keras.models.load_model(model_path)

# %%
reconstructed_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32)]              0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Сравнение моделей

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           reconstructed_model.predict(test_input))

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           test_target)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-21-66689311beed> in <module>
#       1 np.testing.assert_allclose(model.predict(test_input),
# ----> 2                            test_target)
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_allclose(actual, desired, rtol, atol, equal_nan, err_msg, verbose)
#    1529     header = f'Not equal to tolerance rtol={rtol:g}, atol={atol:g}'
#    1530     assert_array_compare(compare, actual, desired, err_msg=str(err_msg),
# -> 1531                          verbose=verbose, header=header, equal_nan=equal_nan)
#    1532
#    1533
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     842                                 verbose=verbose, header=header,
#     843                                 names=('x', 'y'), precision=precision)
# --> 844             raise AssertionError(msg)
#     845     except ValueError:
#     846         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0
#
# Mismatched elements: 2048 / 2048 (100%)
# Max absolute difference: 1.05904447
# Max relative difference: 5452.68150104
#  x: array([[0.414648],
#        [0.36674 ],
#        [0.498998],...
#  y: array([[0.693096],
#        [0.064789],
#        [0.078196],...

# %%
# ?np.testing.assert_allclose

# %%
model == reconstructed_model
# Out:
# False

# %%
model

# %%
reconstructed_model

# %%
0.40000 == 0.399999999999999999999
# Out:
# True

# %% [markdown]
# Продолжение обучения

# %%
reconstructed_model.fit(test_input, test_target, epochs=5)
# Out:
# Epoch 1/5
# 64/64 [==============================] - 0s 1ms/step - loss: 0.1072
# Epoch 2/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1006
# Epoch 3/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0955
# Epoch 4/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0920
# Epoch 5/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0900

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           reconstructed_model.predict(test_input))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-28-d4e40f296811> in <module>
#       1 np.testing.assert_allclose(model.predict(test_input),
# ----> 2                            reconstructed_model.predict(test_input))
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_allclose(actual, desired, rtol, atol, equal_nan, err_msg, verbose)
#    1529     header = f'Not equal to tolerance rtol={rtol:g}, atol={atol:g}'
#    1530     assert_array_compare(compare, actual, desired, err_msg=str(err_msg),
# -> 1531                          verbose=verbose, header=header, equal_nan=equal_nan)
#    1532
#    1533
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     842                                 verbose=verbose, header=header,
#     843                                 names=('x', 'y'), precision=precision)
# --> 844             raise AssertionError(msg)
#     845     except ValueError:
#     846         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0
#
# Mismatched elements: 2048 / 2048 (100%)
# Max absolute difference: 0.35107315
# Max relative difference: 1.8224187
#  x: array([[0.414648],
#        [0.36674 ],
#        [0.498998],...
#  y: array([[0.462785],
#        [0.426133],
#        [0.478146],...

# %%
model.evaluate(test_input, test_target)
# Out:
# 64/64 [==============================] - 0s 1ms/step - loss: 0.1109
# 0.11094482243061066

# %%
reconstructed_model.evaluate(test_input, test_target)
# Out:
# 64/64 [==============================] - 0s 1ms/step - loss: 0.0879
# 0.08793588727712631

# %%
path = "my_model_1"

# %%
reconstructed_model = keras.models.load_model(path)

# %%
reconstructed_model.evaluate(test_input, test_target)
# Out:
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1109
# 0.11094482243061066

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           reconstructed_model.predict(test_input))

# %%
reconstructed_model.fit(test_input, test_target, epochs=5)
# Out:
# Epoch 1/5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.1071
# Epoch 2/5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0997
# Epoch 3/5
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0950
# Epoch 4/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0912
# Epoch 5/5
# 64/64 [==============================] - 0s 2ms/step - loss: 0.0895

# %%
path_2 = "model_2"
reconstructed_model.save(path_2)

# %% [markdown]
# # Сохранение в формате keras h5

# %% [markdown]
# ## Базовая модель

# %%
def get_model():
    inputs = keras.Input(shape=(32,))
    outputs = keras.layers.Dense(1)(inputs)
    model = keras.Model(inputs, outputs)
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    return model

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_input = np.random.random((2048, 32))
test_target = np.random.random((2048, 1))

model.fit(test_input, test_target, epochs=4)
# Out:
# Epoch 1/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4944
# Epoch 2/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2530
# Epoch 3/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2426
# Epoch 4/4
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2315

# %% [markdown]
# Сохранение

# %%
keras_model_path_1 = "my_keras_model.h5"

# %%
model.save(keras_model_path_1, save_format="h5")

# %% [markdown]
# Загрузка модели

# %%
reconstructed_model = keras.models.load_model(keras_model_path_1)

# %%
reconstructed_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Сравнение моделей

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           reconstructed_model.predict(test_input))

# %% [markdown]
# Продолжение обучения

# %%
reconstructed_model.fit(test_input, test_target, epochs=3)
# Out:
# Epoch 1/3
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2193
# Epoch 2/3
# 64/64 [==============================] - 0s 2ms/step - loss: 0.2072
# Epoch 3/3
# 64/64 [==============================] - 0s 2ms/step - loss: 0.1953

# %%
np.testing.assert_allclose(model.predict(test_input), 
                           reconstructed_model.predict(test_input))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-47-d4e40f296811> in <module>
#       1 np.testing.assert_allclose(model.predict(test_input),
# ----> 2                            reconstructed_model.predict(test_input))
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_allclose(actual, desired, rtol, atol, equal_nan, err_msg, verbose)
#    1529     header = f'Not equal to tolerance rtol={rtol:g}, atol={atol:g}'
#    1530     assert_array_compare(compare, actual, desired, err_msg=str(err_msg),
# -> 1531                          verbose=verbose, header=header, equal_nan=equal_nan)
#    1532
#    1533
#
# /usr/local/lib/python3.7/dist-packages/numpy/testing/_private/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     842                                 verbose=verbose, header=header,
#     843                                 names=('x', 'y'), precision=precision)
# --> 844             raise AssertionError(msg)
#     845     except ValueError:
#     846         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0
#
# Mismatched elements: 2048 / 2048 (100%)
# Max absolute difference: 0.17871833
# Max relative difference: 22.952362
#  x: array([[0.640778],
#        [0.279211],
#        [1.133253],...
#  y: array([[0.592221],
#        [0.295313],
#        [1.017259],...

# %%
reconstructed_model.save("my_keras_model_retrained_3_epoch.h5", save_format="h5")

# %% [markdown]
# ---
